# %%
import os
import sys
import torch
import torchvision
from torchvision import datasets, transforms

import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict
from PIL import Image

sys.path.append('..')
os.environ["CUDA_VISIBLE_DEVICES"]="2"

# %% [markdown]
# # Choose variants here:

# %%
trained_model = True
arch = 'ResNet50'

# %% [markdown]
# ## System setup:

# %%
import inversefed
setup = inversefed.utils.system_startup()
defs = inversefed.training_strategy('conservative')

loss_fn, trainloader, validloader =  inversefed.construct_dataloaders('CheXpert', defs, 
                                                                      data_path='../../CheXpert_Dataset/images_256/images/',
                                                                      csv_path = '../../Medical_AT/label/cheXPert_label_.csv')

model = torchvision.models.resnet50(pretrained=trained_model)
num_classes=8
model.fc = torch.nn.Linear(model.fc.in_features, num_classes)
model.to(**setup)
model.eval();
# Out:
# Currently evaluating -------------------------------:
# Monday, 11. April 2022 05:06PM
# CPUs: 20, GPUs: 1 on gpu01.
# GPU : NVIDIA TITAN RTX

# %%
dm = torch.as_tensor(inversefed.consts.cifar10_mean, **setup)[:, None, None]
ds = torch.as_tensor(inversefed.consts.cifar10_std, **setup)[:, None, None]
def plot(tensor):
    tensor = tensor.clone().detach()
    tensor.mul_(ds).add_(dm).clamp_(0, 1)
    if tensor.shape[0] == 1:
        return plt.imshow(tensor[0].permute(1, 2, 0).cpu());
    else:
        fig, axes = plt.subplots(1, tensor.shape[0], figsize=(12, tensor.shape[0]*12))
        for i, im in enumerate(tensor):
            axes[i].imshow(im.permute(1, 2, 0).cpu());

# %% [markdown]
# # Reconstruct

# %% [markdown]
# ### Build the input (ground-truth) gradient

# %%
idx = 10 
# 8112 # the beagle
# 1200 # the owl
# 11794 # the German shepherd
# 19449 # the panda


# np.random.randint(len(validloader.dataset))

img, label = validloader.dataset[idx]
labels = torch.as_tensor((label,), device=setup['device'])
ground_truth = img.to(**setup).unsqueeze(0)
plot(ground_truth);
print(labels);
# Out:
# tensor([[0, 0, 1, 0, 0, 0, 0, 1]], device='cuda:0')

# %%
ground_truth_denormalized = torch.clamp(ground_truth * ds + dm, 0, 1)
torchvision.utils.save_image(ground_truth_denormalized, f'{idx}_{arch}_cxr_input.png')

# %%
model.zero_grad()
target_loss, _, _ = loss_fn(model(ground_truth), labels)
input_gradient = torch.autograd.grad(target_loss, model.parameters())
input_gradient = [grad.detach() for grad in input_gradient]
full_norm = torch.stack([g.norm() for g in input_gradient]).mean()
print(f'Full gradient norm is {full_norm:e}.')
# Out:
# Full gradient norm is 4.336471e-01.

# %% [markdown]
# # Reconstruct the image

# %%
config = dict(signed=True,
              boxed=True,
              cost_fn='sim',
              indices='def',
              weights='equal',
              lr=0.1,
              optim='adam',
              restarts=8,
              max_iterations=24_000,
              total_variation=1e-1,
              init='randn',
              filter='none',
              lr_decay=True,
              scoring_choice='loss')

rec_machine = inversefed.GradientReconstructor(model, (dm, ds), config, num_images=1)
output, stats = rec_machine.reconstruct(input_gradient, labels, img_shape=(3, 224, 224))

test_mse = (output.detach() - ground_truth).pow(2).mean()
feat_mse = (model(output.detach())- model(ground_truth)).pow(2).mean()  
test_psnr = inversefed.metrics.psnr(output, ground_truth)

plot(output)
plt.title(f"Rec. loss: {stats['opt']:2.4f} | MSE: {test_mse:2.4f} "
          f"| PSNR: {test_psnr:4.2f} | FMSE: {feat_mse:2.4e} |");

data = inversefed.metrics.activation_errors(model, output, ground_truth, factor=1/ds)

fig, axes = plt.subplots(2, 3, sharey=False, figsize=(14,8))
axes[0, 0].semilogy(list(data['se'].values())[:-3])
axes[0, 0].set_title('SE')
axes[0, 1].semilogy(list(data['mse'].values())[:-3])
axes[0, 1].set_title('MSE')
axes[0, 2].plot(list(data['sim'].values())[:-3])
axes[0, 2].set_title('Similarity')

convs = [val for key, val in data['mse'].items() if 'conv' in key]
axes[1, 0].semilogy(convs)
axes[1, 0].set_title('MSE - conv layers')
convs = [val for key, val in data['mse'].items() if 'conv1' in key]
axes[1, 1].semilogy(convs)
convs = [val for key, val in data['mse'].items() if 'conv2' in key]
axes[1, 1].semilogy(convs)
axes[1, 1].set_title('MSE - conv1 vs conv2 layers')
bns = [val for key, val in data['mse'].items() if 'bn' in key]
axes[1, 2].plot(bns)
axes[1, 2].set_title('MSE - bn layers')
fig.suptitle('Error between layers');
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-7-58d35d1fd5c4> in <module>
#      15
#      16 rec_machine = inversefed.GradientReconstructor(model, (dm, ds), config, num_images=1)
# ---> 17 output, stats = rec_machine.reconstruct(input_gradient, labels, img_shape=(3, 224, 224))
#      18
#      19 test_mse = (output.detach() - ground_truth).pow(2).mean()
#
# /media/tianyu.han/mri-scratch/DeepLearning/invertinggradients/inversefed/reconstruction_algorithms.py in reconstruct(self, input_data, labels, img_shape, dryrun, eval, tol)
#      93         try:
#      94             for trial in range(self.config['restarts']):
# ---> 95                 x_trial, labels = self._run_trial(x[trial], input_data, labels, dryrun=dryrun)
#      96                 # Finalize
#      97                 scores[trial] = self._score_trial(x_trial, input_data, labels)
#
# /media/tianyu.han/mri-scratch/DeepLearning/invertinggradients/inversefed/reconstruction_algorithms.py in _run_trial(self, x_trial, input_data, labels, dryrun)
#     163             for iteration in range(max_iterations):
#     164                 closure = self._gradient_closure(optimizer, x_trial, input_data, labels)
# --> 165                 rec_loss = optimizer.step(closure)
#     166                 if self.config['lr_decay']:
#     167                     scheduler.step()
#
# ~/anaconda3/lib/python3.8/site-packages/torch/optim/lr_scheduler.py in wrapper(*args, **kwargs)
#      63                 instance._step_count += 1
#      64                 wrapped = func.__get__(instance, cls)
# ---> 65                 return wrapped(*args, **kwargs)
#      66
#      67             # Note that the returned function here is no longer a bound method,
#
# ~/anaconda3/lib/python3.8/site-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#      87                 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#      88                 with torch.autograd.profiler.record_function(profile_name):
# ---> 89                     return func(*args, **kwargs)
#      90             return wrapper
#      91
#
# ~/anaconda3/lib/python3.8/site-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      25         def decorate_context(*args, **kwargs):
#      26             with self.__class__():
# ---> 27                 return func(*args, **kwargs)
#      28         return cast(F, decorate_context)
#      29
#
# ~/anaconda3/lib/python3.8/site-packages/torch/optim/adam.py in step(self, closure)
#      64         if closure is not None:
#      65             with torch.enable_grad():
# ---> 66                 loss = closure()
#      67
#      68         for group in self.param_groups:
#
# /media/tianyu.han/mri-scratch/DeepLearning/invertinggradients/inversefed/reconstruction_algorithms.py in closure()
#     195             optimizer.zero_grad()
#     196             self.model.zero_grad()
# --> 197             loss = self.loss_fn(self.model(x_trial), label)
#     198             gradient = torch.autograd.grad(loss, self.model.parameters(), create_graph=True)
#     199             rec_loss = reconstruction_costs([gradient], input_gradient,
#
# ~/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/anaconda3/lib/python3.8/site-packages/torch/nn/modules/loss.py in forward(self, input, target)
#     611     def forward(self, input: Tensor, target: Tensor) -> Tensor:
#     612         assert self.weight is None or isinstance(self.weight, Tensor)
# --> 613         return F.binary_cross_entropy(input, target, weight=self.weight, reduction=self.reduction)
#     614
#     615
#
# ~/anaconda3/lib/python3.8/site-packages/torch/nn/functional.py in binary_cross_entropy(input, target, weight, size_average, reduce, reduction)
#    2760         weight = weight.expand(new_size)
#    2761
# -> 2762     return torch._C._nn.binary_cross_entropy(input, target, weight, reduction_enum)
#    2763
#    2764
#
# RuntimeError: Found dtype Long but expected Float

# %% [markdown]
# Note the strong prior effect in the reconstructed image, as discussed in Sec. 5.3 of the paper.

# %%
output_denormalized = torch.clamp(output * ds + dm, 0, 1)
torchvision.utils.save_image(output_denormalized, f'{idx}_{arch}_ImageNet_output.png')
